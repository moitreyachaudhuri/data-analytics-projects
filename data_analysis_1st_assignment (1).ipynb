# %% [markdown]
# ***#EXAMPLE OF HOW TO IMPORT AN IMAGE FILE***

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-d42df017-4be9-4353-a743-3589be9a20ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d42df017-4be9-4353-a743-3589be9a20ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("0")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image0 = mpimg.imread("0-image.png")
plt.imshow(image0)
plt.show()

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("1 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image1 = mpimg.imread("1 image.png")
plt.imshow(image1)
plt.show()

# %%
plt.title("2 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image2 = mpimg.imread("2 image.png")
plt.imshow(image2)
plt.show()

# %%
plt.title("3 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image3 = mpimg.imread("3 image.png")
plt.imshow(image3)
plt.show()

# %%
plt.title("4 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image4 = mpimg.imread("4 image.png")
plt.imshow(image4)
plt.show()

# %%
plt.title("5 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image5 = mpimg.imread("5 image.png")
plt.imshow(image5)
plt.show()

# %%
plt.title("6 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image6 = mpimg.imread("6 image.png")
plt.imshow(image6)
plt.show()

# %%
plt.title("7 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image7 = mpimg.imread("7 image.png")
plt.imshow(image7)
plt.show()

# %%
plt.title("8 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image8 = mpimg.imread("8 image.png")
plt.imshow(image8)
plt.show()

# %%
plt.title("9 Image")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
image9 = mpimg.imread("9 image.png")
plt.imshow(image9)
plt.show()

# %% [markdown]
# ***ANOTHER WAY OF IMPORTING IMAGE AND STORING THEM IN AN ARRAY AND VISUALISING THEM IN AN ITERATIVE WAY***

# %%
a=[]
a.append(image0)
a.append(image1)
a.append(image2)
a.append(image3)
a.append(image4)
a.append(image5)
a.append(image6)
a.append(image7)
a.append(image8)
a.append(image9)
for i in range(10):
  plt.imshow(a[i])
  plt.show()

# %% [markdown]
# ***visualising the gray scale value of every image***

# %%
a
# Out:
# [array([[[0.9843137 , 0.9843137 , 0.9529412 , 1.        ],
#          [0.9764706 , 0.9843137 , 0.9647059 , 1.        ],
#          [0.9843137 , 0.9843137 , 0.99215686, 1.        ],
#          ...,
#          [0.9843137 , 0.9843137 , 0.9764706 , 1.        ],
#          [0.98039216, 0.98039216, 0.972549  , 1.        ],
#          [0.98039216, 0.98039216, 0.972549  , 1.        ]],
#
#         [[0.9647059 , 0.99215686, 0.9607843 , 1.        ],
#          [0.9647059 , 0.9882353 , 0.972549  , 1.        ],
#          [0.972549  , 0.9882353 , 1.        , 1.        ],
#          ...,
#          [0.9843137 , 0.9882353 , 0.96862745, 1.        ],
#          [0.9843137 , 0.9882353 , 0.96862745, 1.        ],
#          [0.98039216, 0.9843137 , 0.9647059 , 1.        ]],
#
#         [[0.972549  , 0.99215686, 0.96862745, 1.        ],
#          [0.972549  , 0.99215686, 0.9764706 , 1.        ],
#          [0.98039216, 0.99215686, 1.        , 1.        ],
#          ...,
# ...

# %% [markdown]
# ***FUNCTION FOR IMPLEMENTING EUCLIDIAN DISTANCE***

# %%
def calculateDistance(i1, i2):
    return numpy.sum((i1-i2)**2)

# %% [markdown]
# ***converting images to numpy array for euclidian distance calculation***

# %%
import numpy
b=[]
np_img0 = numpy.array(image0)
np_img1 = numpy.array(image1)
np_img2 = numpy.array(image2)
np_img3 = numpy.array(image3)
np_img4 = numpy.array(image4)
np_img5 = numpy.array(image5)
np_img6 = numpy.array(image6)
np_img7 = numpy.array(image7)
np_img8 = numpy.array(image8)
np_img9 = numpy.array(image9)
b.append(np_img0)
b.append(np_img1)
b.append(np_img2)
b.append(np_img3)
b.append(np_img4)
b.append(np_img5)
b.append(np_img6)
b.append(np_img7)
b.append(np_img8)
b.append(np_img9)
np_img0.shape
#here we can see the shape of the image in numpy
# Out:
# (40, 26, 4)

# %% [markdown]
# ***EUCLIDIAN DISTANCE FROM AN IMAGE FROM ITSELF SHOULD VE ZERO.JUST CHECKING FOR THAT***

# %%
x=calculateDistance(np_img0,np_img0)
y=calculateDistance(np_img1,np_img1)
x,y
#the function works fine as the output is zero for both the test cases
# Out:
# (0.0, 0.0)

# %% [markdown]
# ***importing test data***

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3fb37e19-8871-45ac-bc6f-20f1c2c1350a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3fb37e19-8871-45ac-bc6f-20f1c2c1350a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ***visualising the test data***

# %%
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
 
plt.title("0")
plt.xlabel("X pixel scaling")
plt.ylabel("Y pixels scaling")


 
test = mpimg.imread("test.png")
plt.imshow(test)
plt.show()
#visually it can be seen that the test data is looking like 2.so ideally if we find the euclidian distance against each digit ,the euclidian distance with 2 should be minimum

# %% [markdown]
# ***test code to calculate euclidian distance with training images***

# %%
np_test= numpy.array(test)
c=[]
for i in range(10):
  c.append(calculateDistance(b[i],np_test))
d=min(c)

for i in range(10):
  if c[i]==d:
    result=i
print(c)
print(d,i)

    
#so we see athough the minimum euclid distance should have been with digit 2,due to some error it is matching with 8
# Out:
# [694.7079, 519.21124, 487.29828, 443.83966, 510.96295, 656.3009, 525.1175, 531.8421, 367.831, 581.7617]
# 367.831 9

# %% [markdown]
# ***finding the absolute difference***

# %%
for i in range(10):
  diff =b[i] - np_test 
  print(sum(sum((sum(abs(diff))))))

#here also we see the lowest is matching with 8.
# Out:
# 812.6549072265625
# 623.4587860107422
# 597.8822479248047
# 556.5959930419922
# 624.5725555419922
# 775.7098388671875
# 637.5646667480469
# 634.1332702636719
# 487.56858825683594
# 704.1567840576172
